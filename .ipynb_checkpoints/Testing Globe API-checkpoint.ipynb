# %%
import requests
import json
response = requests.get("https://api.globe.gov/search/v1/measurement/protocol/measureddate/?protocols=mosquito_habitat_mapper&startdate=2020-05-31&enddate=2020-07-03&geojson=TRUE&sample=TRUE")

mosquito_data = response.json()["features"]
mosquito_data
# Out:
# [{'type': 'Feature',
#   'properties': {'countryCode': 'USA',
#    'countryName': 'United States',
#    'elevation': '178.8',
#    'mosquitohabitatmapperAbdomenCloseupPhotoUrls': 'null',
#    'mosquitohabitatmapperBreedingGroundEliminated': 'false',
#    'mosquitohabitatmapperComments': 'null',
#    'mosquitohabitatmapperDataSource': 'GLOBE Observer App',
#    'mosquitohabitatmapperExtraData': 'null',
#    'mosquitohabitatmapperGenus': 'null',
#    'mosquitohabitatmapperLarvaFullBodyPhotoUrls': 'null',
#    'mosquitohabitatmapperLarvaeCount': 'null',
#    'mosquitohabitatmapperLastIdentifyStage': 'identify',
#    'mosquitohabitatmapperMeasuredAt': '2020-06-10T16:41:00',
#    'mosquitohabitatmapperMeasurementElevation': '0',
#    'mosquitohabitatmapperMeasurementLatitude': '39.2539',
#    'mosquitohabitatmapperMeasurementLongitude': '-77.1959',
#    'mosquitohabitatmapperMosquitoAdults': 'null',
#    'mosquitohabitatmapperMosquitoEggCount': 'null',
#    'mosquitohabitatmapperMosquitoEggs': 'null',
#    'mosquitohabitatmapperMosquitoHabitatMapperId': '23007',
#    'mosquitohabitatmapperMosquitoPupae': 'false',
#    'mosquitohabitatmapperSpecies': 'null',
#    'mosquitohabitatmapperUserid': '2877622',
#    'mosquitohabitatmapperWaterSource': 'adult mosquito trap',
#    'mosquitohabitatmapperWaterSourcePhotoUrls': 'https://data.globe.gov/system/photos/2020/06/10/1677868/original.jpg; https://data.globe.gov/system/photos/2020/06/10/1677871/original.jpg',
#    'mosquitohabitatmapperWaterSourceType': 'container: artificial',
#    'organizationId': 'organizationId',
#    'organizationName': 'GPM Satellite Mission',
#    'protocol': 'mosquito_habitat_mapper',
#    'siteId': 'siteId',
#    'siteName': '18SUJ105472'},
#   'geometry': {'type': 'Point', 'coordinates': [-77.196178, 39.253437]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': 'USA',
#    'countryName': 'United States',
#    'elevation': '178.8',
#    'mosquitohabitatmapperAbdomenCloseupPhotoUrls': 'null',
#    'mosquitohabitatmapperBreedingGroundEliminated': 'false',
#    'mosquitohabitatmapperComments': 'null',
#    'mosquitohabitatmapperDataSource': 'GLOBE Observer App',
#    'mosquitohabitatmapperExtraData': 'null',
#    'mosquitohabitatmapperGenus': 'null',
#    'mosquitohabitatmapperLarvaFullBodyPhotoUrls': 'null',
#    'mosquitohabitatmapperLarvaeCount': 'null',
#    'mosquitohabitatmapperLastIdentifyStage': 'identify',
#    'mosquitohabitatmapperMeasuredAt': '2020-06-11T18:25:00',
#    'mosquitohabitatmapperMeasurementElevation': '0',
#    'mosquitohabitatmapperMeasurementLatitude': '39.254',
#    'mosquitohabitatmapperMeasurementLongitude': '-77.1961',
#    'mosquitohabitatmapperMosquitoAdults': 'null',
#    'mosquitohabitatmapperMosquitoEggCount': 'null',
#    'mosquitohabitatmapperMosquitoEggs': 'null',
#    'mosquitohabitatmapperMosquitoHabitatMapperId': '23008',
#    'mosquitohabitatmapperMosquitoPupae': 'false',
#    'mosquitohabitatmapperSpecies': 'null',
#    'mosquitohabitatmapperUserid': '2877622',
#    'mosquitohabitatmapperWaterSource': 'adult mosquito trap',
#    'mosquitohabitatmapperWaterSourcePhotoUrls': 'https://data.globe.gov/system/photos/2020/06/11/1677882/original.jpg; https://data.globe.gov/system/photos/2020/06/11/1677885/original.jpg',
#    'mosquitohabitatmapperWaterSourceType': 'container: artificial',
#    'organizationId': 'organizationId',
#    'organizationName': 'GPM Satellite Mission',
#    'protocol': 'mosquito_habitat_mapper',
#    'siteId': 'siteId',
#    'siteName': '18SUJ105472'},
#   'geometry': {'type': 'Point', 'coordinates': [-77.196178, 39.253437]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': 'USA',
#    'countryName': 'United States',
#    'elevation': '178.8',
#    'mosquitohabitatmapperAbdomenCloseupPhotoUrls': 'null',
#    'mosquitohabitatmapperBreedingGroundEliminated': 'false',
#    'mosquitohabitatmapperComments': 'null',
#    'mosquitohabitatmapperDataSource': 'GLOBE Observer App',
#    'mosquitohabitatmapperExtraData': 'null',
#    'mosquitohabitatmapperGenus': 'null',
#    'mosquitohabitatmapperLarvaFullBodyPhotoUrls': 'null',
#    'mosquitohabitatmapperLarvaeCount': 'null',
#    'mosquitohabitatmapperLastIdentifyStage': 'identify',
#    'mosquitohabitatmapperMeasuredAt': '2020-06-29T14:55:00',
#    'mosquitohabitatmapperMeasurementElevation': '0',
#    'mosquitohabitatmapperMeasurementLatitude': '39.2541',
#    'mosquitohabitatmapperMeasurementLongitude': '-77.1961',
#    'mosquitohabitatmapperMosquitoAdults': 'null',
#    'mosquitohabitatmapperMosquitoEggCount': 'null',
#    'mosquitohabitatmapperMosquitoEggs': 'null',
#    'mosquitohabitatmapperMosquitoHabitatMapperId': '23951',
#    'mosquitohabitatmapperMosquitoPupae': 'false',
#    'mosquitohabitatmapperSpecies': 'null',
#    'mosquitohabitatmapperUserid': '2877622',
#    'mosquitohabitatmapperWaterSource': 'adult mosquito trap',
#    'mosquitohabitatmapperWaterSourcePhotoUrls': 'https://data.globe.gov/system/photos/2020/06/29/1723620/original.jpg; https://data.globe.gov/system/photos/2020/06/29/1723621/original.jpg',
#    'mosquitohabitatmapperWaterSourceType': 'container: artificial',
#    'organizationId': 'organizationId',
#    'organizationName': 'GPM Satellite Mission',
#    'protocol': 'mosquito_habitat_mapper',
#    'siteId': 'siteId',
#    'siteName': '18SUJ105472'},
#   'geometry': {'type': 'Point', 'coordinates': [-77.196178, 39.253437]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': 'USA',
#    'countryName': 'United States',
#    'elevation': '181.1',
#    'mosquitohabitatmapperAbdomenCloseupPhotoUrls': 'null',
#    'mosquitohabitatmapperBreedingGroundEliminated': 'false',
#    'mosquitohabitatmapperComments': 'null',
#    'mosquitohabitatmapperDataSource': 'GLOBE Observer App',
#    'mosquitohabitatmapperExtraData': 'null',
#    'mosquitohabitatmapperGenus': 'null',
#    'mosquitohabitatmapperLarvaFullBodyPhotoUrls': 'null',
#    'mosquitohabitatmapperLarvaeCount': 'null',
#    'mosquitohabitatmapperLastIdentifyStage': 'identify',
#    'mosquitohabitatmapperMeasuredAt': '2020-06-29T14:54:00',
#    'mosquitohabitatmapperMeasurementElevation': '0',
#    'mosquitohabitatmapperMeasurementLatitude': '39.254',
#    'mosquitohabitatmapperMeasurementLongitude': '-77.1963',
#    'mosquitohabitatmapperMosquitoAdults': 'null',
#    'mosquitohabitatmapperMosquitoEggCount': 'null',
#    'mosquitohabitatmapperMosquitoEggs': 'null',
#    'mosquitohabitatmapperMosquitoHabitatMapperId': '23950',
#    'mosquitohabitatmapperMosquitoPupae': 'false',
#    'mosquitohabitatmapperSpecies': 'null',
#    'mosquitohabitatmapperUserid': '2877622',
#    'mosquitohabitatmapperWaterSource': 'adult mosquito trap',
#    'mosquitohabitatmapperWaterSourcePhotoUrls': 'https://data.globe.gov/system/photos/2020/06/29/1723618/original.jpg; https://data.globe.gov/system/photos/2020/06/29/1723619/original.jpg',
#    'mosquitohabitatmapperWaterSourceType': 'container: artificial',
#    'organizationId': 'organizationId',
#    'organizationName': 'GPM Satellite Mission',
#    'protocol': 'mosquito_habitat_mapper',
#    'siteId': 'siteId',
#    'siteName': '18SUJ104472'},
#   'geometry': {'type': 'Point', 'coordinates': [-77.197336, 39.253415]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': 'USA',
#    'countryName': 'United States',
#    'elevation': '181.1',
#    'mosquitohabitatmapperAbdomenCloseupPhotoUrls': 'null',
#    'mosquitohabitatmapperBreedingGroundEliminated': 'false',
#    'mosquitohabitatmapperComments': 'null',
#    'mosquitohabitatmapperDataSource': 'GLOBE Observer App',
#    'mosquitohabitatmapperExtraData': 'null',
#    'mosquitohabitatmapperGenus': 'null',
#    'mosquitohabitatmapperLarvaFullBodyPhotoUrls': 'null',
#    'mosquitohabitatmapperLarvaeCount': 'null',
#    'mosquitohabitatmapperLastIdentifyStage': 'identify',
#    'mosquitohabitatmapperMeasuredAt': '2020-06-29T14:53:00',
#    'mosquitohabitatmapperMeasurementElevation': '0',
#    'mosquitohabitatmapperMeasurementLatitude': '39.254',
#    'mosquitohabitatmapperMeasurementLongitude': '-77.1962',
#    'mosquitohabitatmapperMosquitoAdults': 'null',
#    'mosquitohabitatmapperMosquitoEggCount': 'null',
#    'mosquitohabitatmapperMosquitoEggs': 'null',
#    'mosquitohabitatmapperMosquitoHabitatMapperId': '23949',
#    'mosquitohabitatmapperMosquitoPupae': 'false',
#    'mosquitohabitatmapperSpecies': 'null',
#    'mosquitohabitatmapperUserid': '2877622',
#    'mosquitohabitatmapperWaterSource': 'adult mosquito trap',
#    'mosquitohabitatmapperWaterSourcePhotoUrls': 'https://data.globe.gov/system/photos/2020/06/29/1723616/original.jpg; https://data.globe.gov/system/photos/2020/06/29/1723617/original.jpg',
#    'mosquitohabitatmapperWaterSourceType': 'container: artificial',
#    'organizationId': 'organizationId',
#    'organizationName': 'GPM Satellite Mission',
#    'protocol': 'mosquito_habitat_mapper',
#    'siteId': 'siteId',
#    'siteName': '18SUJ104472'},
#   'geometry': {'type': 'Point', 'coordinates': [-77.197336, 39.253415]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': None,
#    'countryName': None,
#    'elevation': '11.0',
#    'mosquitohabitatmapperAbdomenCloseupPhotoUrls': 'null',
#    'mosquitohabitatmapperBreedingGroundEliminated': 'true',
#    'mosquitohabitatmapperComments': 'null',
#    'mosquitohabitatmapperDataSource': 'GLOBE Observer App',
#    'mosquitohabitatmapperExtraData': 'null',
#    'mosquitohabitatmapperGenus': 'null',
#    'mosquitohabitatmapperLarvaFullBodyPhotoUrls': 'null',
#    'mosquitohabitatmapperLarvaeCount': 'null',
#    'mosquitohabitatmapperLastIdentifyStage': 'identify',
#    'mosquitohabitatmapperMeasuredAt': '2020-06-12T06:13:00',
#    'mosquitohabitatmapperMeasurementElevation': '0',
#    'mosquitohabitatmapperMeasurementLatitude': '8.6422',
#    'mosquitohabitatmapperMeasurementLongitude': '99.8918',
#    'mosquitohabitatmapperMosquitoAdults': 'null',
#    'mosquitohabitatmapperMosquitoEggCount': 'null',
#    'mosquitohabitatmapperMosquitoEggs': 'null',
#    'mosquitohabitatmapperMosquitoHabitatMapperId': '23027',
#    'mosquitohabitatmapperMosquitoPupae': 'false',
#    'mosquitohabitatmapperSpecies': 'null',
#    'mosquitohabitatmapperUserid': '67336396',
#    'mosquitohabitatmapperWaterSource': 'plant clumps (bamboo etc)',
#    'mosquitohabitatmapperWaterSourcePhotoUrls': 'https://data.globe.gov/system/photos/2020/06/12/1678884/original.jpg',
#    'mosquitohabitatmapperWaterSourceType': 'container: natural',
#    'organizationId': 'organizationId',
#    'organizationName': 'Thailand Citizen Science',
#    'protocol': 'mosquito_habitat_mapper',
#    'siteId': 'siteId',
#    'siteName': '47PNK981554'},
#   'geometry': {'type': 'Point', 'coordinates': [99.891622, 8.642111]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': None,
#    'countryName': None,
#    'elevation': '11.0',
#    'mosquitohabitatmapperAbdomenCloseupPhotoUrls': 'null',
#    'mosquitohabitatmapperBreedingGroundEliminated': 'false',
#    'mosquitohabitatmapperComments': 'null',
#    'mosquitohabitatmapperDataSource': 'GLOBE Observer App',
#    'mosquitohabitatmapperExtraData': 'null',
#    'mosquitohabitatmapperGenus': 'null',
#    'mosquitohabitatmapperLarvaFullBodyPhotoUrls': 'null',
#    'mosquitohabitatmapperLarvaeCount': 'null',
#    'mosquitohabitatmapperLastIdentifyStage': 'identify',
#    'mosquitohabitatmapperMeasuredAt': '2020-06-12T06:17:00',
#    'mosquitohabitatmapperMeasurementElevation': '0',
#    'mosquitohabitatmapperMeasurementLatitude': '8.6422',
#    'mosquitohabitatmapperMeasurementLongitude': '99.8918',
#    'mosquitohabitatmapperMosquitoAdults': 'null',
#    'mosquitohabitatmapperMosquitoEggCount': 'null',
#    'mosquitohabitatmapperMosquitoEggs': 'null',
#    'mosquitohabitatmapperMosquitoHabitatMapperId': '23024',
#    'mosquitohabitatmapperMosquitoPupae': 'false',
#    'mosquitohabitatmapperSpecies': 'null',
#    'mosquitohabitatmapperUserid': '67336138',
#    'mosquitohabitatmapperWaterSource': 'plant clumps (bamboo etc)',
#    'mosquitohabitatmapperWaterSourcePhotoUrls': 'rejected',
#    'mosquitohabitatmapperWaterSourceType': 'container: natural',
#    'organizationId': 'organizationId',
#    'organizationName': 'Thailand Citizen Science',
#    'protocol': 'mosquito_habitat_mapper',
#    'siteId': 'siteId',
#    'siteName': '47PNK981554'},
#   'geometry': {'type': 'Point', 'coordinates': [99.891622, 8.642111]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': None,
#    'countryName': None,
#    'elevation': '11.0',
#    'mosquitohabitatmapperAbdomenCloseupPhotoUrls': 'null',
#    'mosquitohabitatmapperBreedingGroundEliminated': 'false',
#    'mosquitohabitatmapperComments': 'null',
#    'mosquitohabitatmapperDataSource': 'GLOBE Observer App',
#    'mosquitohabitatmapperExtraData': 'null',
#    'mosquitohabitatmapperGenus': 'null',
#    'mosquitohabitatmapperLarvaFullBodyPhotoUrls': 'null',
#    'mosquitohabitatmapperLarvaeCount': 'null',
#    'mosquitohabitatmapperLastIdentifyStage': 'identify',
#    'mosquitohabitatmapperMeasuredAt': '2020-06-12T06:05:00',
#    'mosquitohabitatmapperMeasurementElevation': '0',
#    'mosquitohabitatmapperMeasurementLatitude': '8.6422',
#    'mosquitohabitatmapperMeasurementLongitude': '99.8918',
#    'mosquitohabitatmapperMosquitoAdults': 'null',
#    'mosquitohabitatmapperMosquitoEggCount': 'null',
#    'mosquitohabitatmapperMosquitoEggs': 'null',
#    'mosquitohabitatmapperMosquitoHabitatMapperId': '23021',
#    'mosquitohabitatmapperMosquitoPupae': 'false',
#    'mosquitohabitatmapperSpecies': 'null',
#    'mosquitohabitatmapperUserid': '67336280',
#    'mosquitohabitatmapperWaterSource': 'fountain or bird bath',
#    'mosquitohabitatmapperWaterSourcePhotoUrls': 'https://data.globe.gov/system/photos/2020/06/12/1678869/original.jpg',
#    'mosquitohabitatmapperWaterSourceType': 'container: artificial',
#    'organizationId': 'organizationId',
#    'organizationName': 'Thailand Citizen Science',
#    'protocol': 'mosquito_habitat_mapper',
#    'siteId': 'siteId',
#    'siteName': '47PNK981554'},
#   'geometry': {'type': 'Point', 'coordinates': [99.891622, 8.642111]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': None,
#    'countryName': None,
#    'elevation': '11.0',
#    'mosquitohabitatmapperAbdomenCloseupPhotoUrls': 'null',
#    'mosquitohabitatmapperBreedingGroundEliminated': 'false',
#    'mosquitohabitatmapperComments': 'null',
#    'mosquitohabitatmapperDataSource': 'GLOBE Observer App',
#    'mosquitohabitatmapperExtraData': 'null',
#    'mosquitohabitatmapperGenus': 'null',
#    'mosquitohabitatmapperLarvaFullBodyPhotoUrls': 'null',
#    'mosquitohabitatmapperLarvaeCount': 'null',
#    'mosquitohabitatmapperLastIdentifyStage': 'identify',
#    'mosquitohabitatmapperMeasuredAt': '2020-06-12T06:04:00',
#    'mosquitohabitatmapperMeasurementElevation': '0',
#    'mosquitohabitatmapperMeasurementLatitude': '8.6422',
#    'mosquitohabitatmapperMeasurementLongitude': '99.8918',
#    'mosquitohabitatmapperMosquitoAdults': 'null',
#    'mosquitohabitatmapperMosquitoEggCount': 'null',
#    'mosquitohabitatmapperMosquitoEggs': 'null',
#    'mosquitohabitatmapperMosquitoHabitatMapperId': '23019',
#    'mosquitohabitatmapperMosquitoPupae': 'false',
#    'mosquitohabitatmapperSpecies': 'null',
#    'mosquitohabitatmapperUserid': '67335650',
#    'mosquitohabitatmapperWaterSource': 'lake',
#    'mosquitohabitatmapperWaterSourcePhotoUrls': 'rejected',
#    'mosquitohabitatmapperWaterSourceType': 'still: lake/pond/swamp',
#    'organizationId': 'organizationId',
#    'organizationName': 'Thailand Citizen Science',
#    'protocol': 'mosquito_habitat_mapper',
#    'siteId': 'siteId',
#    'siteName': '47PNK981554'},
#   'geometry': {'type': 'Point', 'coordinates': [99.891622, 8.642111]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': None,
#    'countryName': None,
#    'elevation': '11.0',
#    'mosquitohabitatmapperAbdomenCloseupPhotoUrls': 'null',
#    'mosquitohabitatmapperBreedingGroundEliminated': 'false',
#    'mosquitohabitatmapperComments': 'null',
#    'mosquitohabitatmapperDataSource': 'GLOBE Observer App',
#    'mosquitohabitatmapperExtraData': 'null',
#    'mosquitohabitatmapperGenus': 'null',
#    'mosquitohabitatmapperLarvaFullBodyPhotoUrls': 'null',
#    'mosquitohabitatmapperLarvaeCount': 'null',
#    'mosquitohabitatmapperLastIdentifyStage': 'identify',
#    'mosquitohabitatmapperMeasuredAt': '2020-06-12T06:05:00',
#    'mosquitohabitatmapperMeasurementElevation': '0',
#    'mosquitohabitatmapperMeasurementLatitude': '8.6422',
#    'mosquitohabitatmapperMeasurementLongitude': '99.8918',
#    'mosquitohabitatmapperMosquitoAdults': 'null',
#    'mosquitohabitatmapperMosquitoEggCount': 'null',
#    'mosquitohabitatmapperMosquitoEggs': 'null',
#    'mosquitohabitatmapperMosquitoHabitatMapperId': '23020',
#    'mosquitohabitatmapperMosquitoPupae': 'false',
#    'mosquitohabitatmapperSpecies': 'null',
#    'mosquitohabitatmapperUserid': '67336138',
#    'mosquitohabitatmapperWaterSource': 'ditch',
#    'mosquitohabitatmapperWaterSourcePhotoUrls': 'https://data.globe.gov/system/photos/2020/06/12/1678876/original.jpg',
#    'mosquitohabitatmapperWaterSourceType': 'still: lake/pond/swamp',
#    'organizationId': 'organizationId',
#    'organizationName': 'Thailand Citizen Science',
#    'protocol': 'mosquito_habitat_mapper',
#    'siteId': 'siteId',
#    'siteName': '47PNK981554'},
#   'geometry': {'type': 'Point', 'coordinates': [99.891622, 8.642111]}}]

# %%
import pandas as pd
data_df_mosquito = pd.DataFrame(mosquito_data)

mosquito_list = []
for index, row in data_df_mosquito.iterrows():
    mosquito_data_dict_1 = {**data_df_mosquito.loc[index, "properties"], **data_df_mosquito.loc[index, "geometry"] }
    mosquito_list.append(mosquito_data_dict_1)

# %%
key_data = ["coordinates", "mosquitohabitatmapperComments", "mosquitohabitatmapperSpecies", "mosquitohabitatmapperMosquitoPupae", "mosquitohabitatmapperLarvaeCount", "mosquitohabitatmapperMosquitoEggCount"]
mosquito_data = pd.DataFrame(mosquito_list)[key_data]
mosquito_data
# Out:
#                coordinates mosquitohabitatmapperComments  \
# 0  [-77.196178, 39.253437]                          null
# 1  [-77.196178, 39.253437]                          null
# 2  [-77.196178, 39.253437]                          null
# 3  [-77.197336, 39.253415]                          null
# 4  [-77.197336, 39.253415]                          null
# 5    [99.891622, 8.642111]                          null
# 6    [99.891622, 8.642111]                          null
# 7    [99.891622, 8.642111]                          null
# 8    [99.891622, 8.642111]                          null
# 9    [99.891622, 8.642111]                          null
#
#   mosquitohabitatmapperSpecies mosquitohabitatmapperMosquitoPupae  \
# 0                         null                              false
# 1                         null                              false
# 2                         null                              false
# 3                         null                              false
# 4                         null                              false
# 5                         null                              false
# 6                         null                              false
# 7                         null                              false
# 8                         null                              false
# 9                         null                              false
#
#   mosquitohabitatmapperLarvaeCount mosquitohabitatmapperMosquitoEggCount
# 0                             null                                  null
# 1                             null                                  null
# 2                             null                                  null
# 3                             null                                  null
# 4                             null                                  null
# 5                             null                                  null
# 6                             null                                  null
# 7                             null                                  null
# 8                             null                                  null
# 9                             null                                  null

# %%
land_cover_url = "https://api.globe.gov/search/v1/measurement/protocol/measureddate/?protocols=land_covers&startdate=2020-05-31&enddate=2020-07-03&geojson=TRUE&sample=TRUE"
response_land_cover = requests.get(land_cover_url)

land_data = response_land_cover.json()["features"]
land_data
# Out:
# [{'type': 'Feature',
#   'properties': {'countryCode': 'SAU',
#    'countryName': 'Saudi Arabia',
#    'elevation': '7.1',
#    'landcoversDataSource': 'GLOBE Data Entry Site Definition',
#    'landcoversDownwardCaption': 'null',
#    'landcoversDownwardExtraData': 'null',
#    'landcoversDownwardPhotoUrl': 'null',
#    'landcoversDryGround': 'null',
#    'landcoversEastCaption': 'null',
#    'landcoversEastClassifications': 'null',
#    'landcoversEastExtraData': 'null',
#    'landcoversEastPhotoUrl': 'null',
#    'landcoversFieldNotes': 'urban land cover',
#    'landcoversLandCoverId': '32791',
#    'landcoversLeavesOnTrees': 'null',
#    'landcoversMeasuredAt': '2020-06-18T19:19:16.966165',
#    'landcoversMucCode': 'M94',
#    'landcoversMucDescription': 'Urban, Other',
#    'landcoversMucDetails': 'null',
#    'landcoversMuddy': 'null',
#    'landcoversNorthCaption': 'null',
#    'landcoversNorthClassifications': 'null',
#    'landcoversNorthExtraData': 'null',
#    'landcoversNorthPhotoUrl': 'null',
#    'landcoversRainingSnowing': 'null',
#    'landcoversSnowIce': 'null',
#    'landcoversSouthCaption': 'null',
#    'landcoversSouthClassifications': 'null',
#    'landcoversSouthExtraData': 'null',
#    'landcoversSouthPhotoUrl': 'null',
#    'landcoversStandingWater': 'null',
#    'landcoversUpwardCaption': 'null',
#    'landcoversUpwardExtraData': 'null',
#    'landcoversUpwardPhotoUrl': 'null',
#    'landcoversUserid': 'null',
#    'landcoversWestCaption': 'null',
#    'landcoversWestClassifications': 'null',
#    'landcoversWestExtraData': 'null',
#    'landcoversWestPhotoUrl': 'null',
#    'organizationId': 'organizationId',
#    'organizationName': 'Al-Farouq Intermediate School at Jeddah',
#    'protocol': 'land_covers',
#    'siteId': 'siteId',
#    'siteName': 'Soil16-Heraa'},
#   'geometry': {'type': 'Point', 'coordinates': [39.138221, 21.611502]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': 'SAU',
#    'countryName': 'Saudi Arabia',
#    'elevation': '7.1',
#    'landcoversDataSource': 'GLOBE Data Entry Site Definition',
#    'landcoversDownwardCaption': 'null',
#    'landcoversDownwardExtraData': 'null',
#    'landcoversDownwardPhotoUrl': 'null',
#    'landcoversDryGround': 'null',
#    'landcoversEastCaption': 'null',
#    'landcoversEastClassifications': 'null',
#    'landcoversEastExtraData': 'null',
#    'landcoversEastPhotoUrl': 'null',
#    'landcoversFieldNotes': 'null',
#    'landcoversLandCoverId': '32790',
#    'landcoversLeavesOnTrees': 'null',
#    'landcoversMeasuredAt': '2020-06-18T19:09:19.742489',
#    'landcoversMucCode': 'M91',
#    'landcoversMucDescription': 'Urban, Residential',
#    'landcoversMucDetails': 'null',
#    'landcoversMuddy': 'null',
#    'landcoversNorthCaption': 'null',
#    'landcoversNorthClassifications': 'null',
#    'landcoversNorthExtraData': 'null',
#    'landcoversNorthPhotoUrl': 'null',
#    'landcoversRainingSnowing': 'null',
#    'landcoversSnowIce': 'null',
#    'landcoversSouthCaption': 'null',
#    'landcoversSouthClassifications': 'null',
#    'landcoversSouthExtraData': 'null',
#    'landcoversSouthPhotoUrl': 'null',
#    'landcoversStandingWater': 'null',
#    'landcoversUpwardCaption': 'null',
#    'landcoversUpwardExtraData': 'null',
#    'landcoversUpwardPhotoUrl': 'null',
#    'landcoversUserid': 'null',
#    'landcoversWestCaption': 'null',
#    'landcoversWestClassifications': 'null',
#    'landcoversWestExtraData': 'null',
#    'landcoversWestPhotoUrl': 'null',
#    'organizationId': 'organizationId',
#    'organizationName': 'Al-Farouq Intermediate School at Jeddah',
#    'protocol': 'land_covers',
#    'siteId': 'siteId',
#    'siteName': 'Soil16-Heraa'},
#   'geometry': {'type': 'Point', 'coordinates': [39.138221, 21.611502]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': None,
#    'countryName': None,
#    'elevation': '1596.6',
#    'landcoversDataSource': 'GLOBE Observer App',
#    'landcoversDownwardCaption': '',
#    'landcoversDownwardExtraData': '(source: app, (compassData.horizon: -88.41393802903268))',
#    'landcoversDownwardPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/27/1719230/original.jpg',
#    'landcoversDryGround': 'true',
#    'landcoversEastCaption': '',
#    'landcoversEastClassifications': 'null',
#    'landcoversEastExtraData': '(source: app, (compassData.horizon: 3.1678197783414106))',
#    'landcoversEastPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/27/1719226/original.jpg',
#    'landcoversFieldNotes': 'Muddy conditions.',
#    'landcoversLandCoverId': '33839',
#    'landcoversLeavesOnTrees': 'true',
#    'landcoversMeasuredAt': '2020-06-27T21:14:00',
#    'landcoversMeasurementElevation': '1597.1',
#    'landcoversMeasurementLatitude': '40.0147',
#    'landcoversMeasurementLongitude': '-105.235',
#    'landcoversMucCode': 'null',
#    'landcoversMucDescription': 'null',
#    'landcoversMucDetails': '',
#    'landcoversMuddy': 'true',
#    'landcoversNorthCaption': '',
#    'landcoversNorthClassifications': 'null',
#    'landcoversNorthExtraData': '(source: app, (compassData.horizon: 1.7187161076911508))',
#    'landcoversNorthPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/27/1719225/original.jpg',
#    'landcoversRainingSnowing': 'false',
#    'landcoversSnowIce': 'false',
#    'landcoversSouthCaption': '',
#    'landcoversSouthClassifications': 'null',
#    'landcoversSouthExtraData': '(source: app, (compassData.horizon: 1.3147597433755749))',
#    'landcoversSouthPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/27/1719227/original.jpg',
#    'landcoversStandingWater': 'false',
#    'landcoversUpwardCaption': '',
#    'landcoversUpwardExtraData': '(source: app, (compassData.horizon: 88.1844509605488))',
#    'landcoversUpwardPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/27/1719229/original.jpg',
#    'landcoversUserid': '67185765',
#    'landcoversWestCaption': '',
#    'landcoversWestClassifications': 'null',
#    'landcoversWestExtraData': '(source: app, (compassData.horizon: 3.8912813865824916))',
#    'landcoversWestPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/27/1719228/original.jpg',
#    'organizationId': 'organizationId',
#    'organizationName': 'United States of America Citizen Science',
#    'protocol': 'land_covers',
#    'siteId': 'siteId',
#    'siteName': '13TDE799294'},
#   'geometry': {'type': 'Point', 'coordinates': [-105.235524, 40.014562]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': None,
#    'countryName': None,
#    'elevation': '1612.4',
#    'landcoversDataSource': 'GLOBE Observer App',
#    'landcoversDownwardCaption': '',
#    'landcoversDownwardExtraData': '(source: app, (compassData.horizon: -86.3575107538897))',
#    'landcoversDownwardPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/27/1719203/original.jpg',
#    'landcoversDryGround': 'true',
#    'landcoversEastCaption': '',
#    'landcoversEastClassifications': 'null',
#    'landcoversEastExtraData': '(source: app, (compassData.horizon: 0.44272542614389465))',
#    'landcoversEastPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/27/1719199/original.jpg',
#    'landcoversFieldNotes': 'No mosquito habitat. However pavement has cracks and holes good for mosquitoes.',
#    'landcoversLandCoverId': '33834',
#    'landcoversLeavesOnTrees': 'true',
#    'landcoversMeasuredAt': '2020-06-27T21:00:00',
#    'landcoversMeasurementElevation': '1610.8',
#    'landcoversMeasurementLatitude': '40.02',
#    'landcoversMeasurementLongitude': '-105.2585',
#    'landcoversMucCode': 'null',
#    'landcoversMucDescription': 'null',
#    'landcoversMucDetails': '',
#    'landcoversMuddy': 'false',
#    'landcoversNorthCaption': '',
#    'landcoversNorthClassifications': 'null',
#    'landcoversNorthExtraData': '(source: app, (compassData.horizon: -0.5178247855106974))',
#    'landcoversNorthPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/27/1719198/original.jpg',
#    'landcoversRainingSnowing': 'false',
#    'landcoversSnowIce': 'false',
#    'landcoversSouthCaption': '',
#    'landcoversSouthClassifications': 'null',
#    'landcoversSouthExtraData': '(source: app, (compassData.horizon: 0.8211816219390045))',
#    'landcoversSouthPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/27/1719200/original.jpg',
#    'landcoversStandingWater': 'false',
#    'landcoversUpwardCaption': '',
#    'landcoversUpwardExtraData': '(source: app, (compassData.horizon: 88.60742878939793))',
#    'landcoversUpwardPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/27/1719202/original.jpg',
#    'landcoversUserid': '67185765',
#    'landcoversWestCaption': '',
#    'landcoversWestClassifications': 'null',
#    'landcoversWestExtraData': '(source: app, (compassData.horizon: 6.786672520875982))',
#    'landcoversWestPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/27/1719201/original.jpg',
#    'organizationId': 'organizationId',
#    'organizationName': 'United States of America Citizen Science',
#    'protocol': 'land_covers',
#    'siteId': 'siteId',
#    'siteName': '13TDE779300'},
#   'geometry': {'type': 'Point', 'coordinates': [-105.258979, 40.019918]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': 'SAU',
#    'countryName': 'Saudi Arabia',
#    'elevation': '1651.8',
#    'landcoversDataSource': 'GLOBE Data Entry Site Definition',
#    'landcoversDownwardCaption': 'null',
#    'landcoversDownwardExtraData': 'null',
#    'landcoversDownwardPhotoUrl': 'null',
#    'landcoversDryGround': 'null',
#    'landcoversEastCaption': 'null',
#    'landcoversEastClassifications': 'null',
#    'landcoversEastExtraData': 'null',
#    'landcoversEastPhotoUrl': 'null',
#    'landcoversFieldNotes': '-',
#    'landcoversLandCoverId': '33928',
#    'landcoversLeavesOnTrees': 'null',
#    'landcoversMeasuredAt': '2020-06-28T23:48:54.895162',
#    'landcoversMucCode': 'M81',
#    'landcoversMucDescription': 'Cultivated Land, Agriculture',
#    'landcoversMucDetails': 'null',
#    'landcoversMuddy': 'null',
#    'landcoversNorthCaption': 'null',
#    'landcoversNorthClassifications': 'null',
#    'landcoversNorthExtraData': 'null',
#    'landcoversNorthPhotoUrl': 'null',
#    'landcoversRainingSnowing': 'null',
#    'landcoversSnowIce': 'null',
#    'landcoversSouthCaption': 'null',
#    'landcoversSouthClassifications': 'null',
#    'landcoversSouthExtraData': 'null',
#    'landcoversSouthPhotoUrl': 'null',
#    'landcoversStandingWater': 'null',
#    'landcoversUpwardCaption': 'null',
#    'landcoversUpwardExtraData': 'null',
#    'landcoversUpwardPhotoUrl': 'null',
#    'landcoversUserid': 'null',
#    'landcoversWestCaption': 'null',
#    'landcoversWestClassifications': 'null',
#    'landcoversWestExtraData': 'null',
#    'landcoversWestPhotoUrl': 'null',
#    'organizationId': 'organizationId',
#    'organizationName': 'Officers Residece Intermediate Girls School at Taif',
#    'protocol': 'land_covers',
#    'siteId': 'siteId',
#    'siteName': 'Officers Residece Intermediate Girls School at Taif'},
#   'geometry': {'type': 'Point', 'coordinates': [40.969218, 24.229192]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': 'SAU',
#    'countryName': 'Saudi Arabia',
#    'elevation': '1651.8',
#    'landcoversDataSource': 'GLOBE Data Entry Site Definition',
#    'landcoversDownwardCaption': 'null',
#    'landcoversDownwardExtraData': 'null',
#    'landcoversDownwardPhotoUrl': 'null',
#    'landcoversDryGround': 'null',
#    'landcoversEastCaption': 'null',
#    'landcoversEastClassifications': 'null',
#    'landcoversEastExtraData': 'null',
#    'landcoversEastPhotoUrl': 'null',
#    'landcoversFieldNotes': '-',
#    'landcoversLandCoverId': '33973',
#    'landcoversLeavesOnTrees': 'null',
#    'landcoversMeasuredAt': '2020-06-29T10:12:38.706856',
#    'landcoversMucCode': 'M81',
#    'landcoversMucDescription': 'Cultivated Land, Agriculture',
#    'landcoversMucDetails': 'null',
#    'landcoversMuddy': 'null',
#    'landcoversNorthCaption': 'null',
#    'landcoversNorthClassifications': 'null',
#    'landcoversNorthExtraData': 'null',
#    'landcoversNorthPhotoUrl': 'null',
#    'landcoversRainingSnowing': 'null',
#    'landcoversSnowIce': 'null',
#    'landcoversSouthCaption': 'null',
#    'landcoversSouthClassifications': 'null',
#    'landcoversSouthExtraData': 'null',
#    'landcoversSouthPhotoUrl': 'null',
#    'landcoversStandingWater': 'null',
#    'landcoversUpwardCaption': 'null',
#    'landcoversUpwardExtraData': 'null',
#    'landcoversUpwardPhotoUrl': 'null',
#    'landcoversUserid': 'null',
#    'landcoversWestCaption': 'null',
#    'landcoversWestClassifications': 'null',
#    'landcoversWestExtraData': 'null',
#    'landcoversWestPhotoUrl': 'null',
#    'organizationId': 'organizationId',
#    'organizationName': 'Officers Residece Intermediate Girls School at Taif',
#    'protocol': 'land_covers',
#    'siteId': 'siteId',
#    'siteName': 'Officers Residece Intermediate Girls School at Taif'},
#   'geometry': {'type': 'Point', 'coordinates': [40.969218, 24.229192]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': 'SAU',
#    'countryName': 'Saudi Arabia',
#    'elevation': '1651.8',
#    'landcoversDataSource': 'GLOBE Data Entry Site Definition',
#    'landcoversDownwardCaption': 'null',
#    'landcoversDownwardExtraData': 'null',
#    'landcoversDownwardPhotoUrl': 'null',
#    'landcoversDryGround': 'null',
#    'landcoversEastCaption': 'null',
#    'landcoversEastClassifications': 'null',
#    'landcoversEastExtraData': 'null',
#    'landcoversEastPhotoUrl': 'null',
#    'landcoversFieldNotes': '-',
#    'landcoversLandCoverId': '34075',
#    'landcoversLeavesOnTrees': 'null',
#    'landcoversMeasuredAt': '2020-06-30T14:43:06.177942',
#    'landcoversMucCode': 'M81',
#    'landcoversMucDescription': 'Cultivated Land, Agriculture',
#    'landcoversMucDetails': 'null',
#    'landcoversMuddy': 'null',
#    'landcoversNorthCaption': 'null',
#    'landcoversNorthClassifications': 'null',
#    'landcoversNorthExtraData': 'null',
#    'landcoversNorthPhotoUrl': 'null',
#    'landcoversRainingSnowing': 'null',
#    'landcoversSnowIce': 'null',
#    'landcoversSouthCaption': 'null',
#    'landcoversSouthClassifications': 'null',
#    'landcoversSouthExtraData': 'null',
#    'landcoversSouthPhotoUrl': 'null',
#    'landcoversStandingWater': 'null',
#    'landcoversUpwardCaption': 'null',
#    'landcoversUpwardExtraData': 'null',
#    'landcoversUpwardPhotoUrl': 'null',
#    'landcoversUserid': 'null',
#    'landcoversWestCaption': 'null',
#    'landcoversWestClassifications': 'null',
#    'landcoversWestExtraData': 'null',
#    'landcoversWestPhotoUrl': 'null',
#    'organizationId': 'organizationId',
#    'organizationName': 'Officers Residece Intermediate Girls School at Taif',
#    'protocol': 'land_covers',
#    'siteId': 'siteId',
#    'siteName': 'Officers Residece Intermediate Girls School at Taif'},
#   'geometry': {'type': 'Point', 'coordinates': [40.969218, 24.229192]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': 'SAU',
#    'countryName': 'Saudi Arabia',
#    'elevation': '1651.8',
#    'landcoversDataSource': 'GLOBE Data Entry Site Definition',
#    'landcoversDownwardCaption': 'null',
#    'landcoversDownwardExtraData': 'null',
#    'landcoversDownwardPhotoUrl': 'null',
#    'landcoversDryGround': 'null',
#    'landcoversEastCaption': 'null',
#    'landcoversEastClassifications': 'null',
#    'landcoversEastExtraData': 'null',
#    'landcoversEastPhotoUrl': 'null',
#    'landcoversFieldNotes': '-',
#    'landcoversLandCoverId': '34073',
#    'landcoversLeavesOnTrees': 'null',
#    'landcoversMeasuredAt': '2020-06-30T13:47:29.571678',
#    'landcoversMucCode': 'M81',
#    'landcoversMucDescription': 'Cultivated Land, Agriculture',
#    'landcoversMucDetails': 'null',
#    'landcoversMuddy': 'null',
#    'landcoversNorthCaption': 'null',
#    'landcoversNorthClassifications': 'null',
#    'landcoversNorthExtraData': 'null',
#    'landcoversNorthPhotoUrl': 'null',
#    'landcoversRainingSnowing': 'null',
#    'landcoversSnowIce': 'null',
#    'landcoversSouthCaption': 'null',
#    'landcoversSouthClassifications': 'null',
#    'landcoversSouthExtraData': 'null',
#    'landcoversSouthPhotoUrl': 'null',
#    'landcoversStandingWater': 'null',
#    'landcoversUpwardCaption': 'null',
#    'landcoversUpwardExtraData': 'null',
#    'landcoversUpwardPhotoUrl': 'null',
#    'landcoversUserid': 'null',
#    'landcoversWestCaption': 'null',
#    'landcoversWestClassifications': 'null',
#    'landcoversWestExtraData': 'null',
#    'landcoversWestPhotoUrl': 'null',
#    'organizationId': 'organizationId',
#    'organizationName': 'Officers Residece Intermediate Girls School at Taif',
#    'protocol': 'land_covers',
#    'siteId': 'siteId',
#    'siteName': 'Officers Residece Intermediate Girls School at Taif'},
#   'geometry': {'type': 'Point', 'coordinates': [40.969218, 24.229192]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': 'USA',
#    'countryName': 'United States',
#    'elevation': '192.1',
#    'landcoversDataSource': 'GLOBE Observer App',
#    'landcoversDownwardCaption': 'null',
#    'landcoversDownwardExtraData': 'null',
#    'landcoversDownwardPhotoUrl': 'null',
#    'landcoversDryGround': 'true',
#    'landcoversEastCaption': '',
#    'landcoversEastClassifications': 'null',
#    'landcoversEastExtraData': '(source: app, (compassData.horizon: -81.15490722151463))',
#    'landcoversEastPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/02/1659863/original.jpg',
#    'landcoversFieldNotes': '(none)',
#    'landcoversLandCoverId': '31734',
#    'landcoversLeavesOnTrees': 'true',
#    'landcoversMeasuredAt': '2020-06-02T12:44:00',
#    'landcoversMeasurementElevation': '192.1',
#    'landcoversMeasurementLatitude': '41.5744',
#    'landcoversMeasurementLongitude': '-83.6251',
#    'landcoversMucCode': 'null',
#    'landcoversMucDescription': 'null',
#    'landcoversMucDetails': '',
#    'landcoversMuddy': 'false',
#    'landcoversNorthCaption': '',
#    'landcoversNorthClassifications': 'null',
#    'landcoversNorthExtraData': '(source: app, (compassData.horizon: 36.8326249443582))',
#    'landcoversNorthPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/02/1659862/original.jpg',
#    'landcoversRainingSnowing': 'false',
#    'landcoversSnowIce': 'false',
#    'landcoversSouthCaption': '',
#    'landcoversSouthClassifications': 'null',
#    'landcoversSouthExtraData': '(source: app, (compassData.horizon: 19.744543351330762))',
#    'landcoversSouthPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/02/1659864/original.jpg',
#    'landcoversStandingWater': 'false',
#    'landcoversUpwardCaption': 'null',
#    'landcoversUpwardExtraData': 'null',
#    'landcoversUpwardPhotoUrl': 'null',
#    'landcoversUserid': '398545',
#    'landcoversWestCaption': '',
#    'landcoversWestClassifications': 'null',
#    'landcoversWestExtraData': '(source: app, (compassData.horizon: 24.557487050487595))',
#    'landcoversWestPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/02/1659865/original.jpg',
#    'organizationId': 'organizationId',
#    'organizationName': 'Bowling Green State University (USOHP793)',
#    'protocol': 'land_covers',
#    'siteId': 'siteId',
#    'siteName': '17TKG811058'},
#   'geometry': {'type': 'Point', 'coordinates': [-83.625603, 41.573917]}},
#  {'type': 'Feature',
#   'properties': {'countryCode': 'USA',
#    'countryName': 'United States',
#    'elevation': '192.1',
#    'landcoversDataSource': 'GLOBE Observer App',
#    'landcoversDownwardCaption': '',
#    'landcoversDownwardExtraData': '(source: app, (compassData.horizon: -89.58904057088495))',
#    'landcoversDownwardPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/02/1660201/original.jpg',
#    'landcoversDryGround': 'true',
#    'landcoversEastCaption': '',
#    'landcoversEastClassifications': '10% MUC 11 (n) [Trees, Loosely Spaced, Evergreen - Needle Leaved]; 10% MUC 12 (n) [Trees, Loosely Spaced, Deciduous - Needle Leaved]; 10% MUC 32 (l) [Shrubs, Loosely Spaced, Short Deciduous]; 70% MUC 91 [Urban, Residential Property]',
#    'landcoversEastExtraData': '(source: app, (compassData.horizon: 25.35176391756052))',
#    'landcoversEastPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/02/1660195/original.jpg',
#    'landcoversFieldNotes': '(none)',
#    'landcoversLandCoverId': '31736',
#    'landcoversLeavesOnTrees': 'true',
#    'landcoversMeasuredAt': '2020-06-02T12:51:00',
#    'landcoversMeasurementElevation': '191.9',
#    'landcoversMeasurementLatitude': '41.5747',
#    'landcoversMeasurementLongitude': '-83.625',
#    'landcoversMucCode': 'M91',
#    'landcoversMucDescription': 'Urban, Residential Property',
#    'landcoversMucDetails': '',
#    'landcoversMuddy': 'false',
#    'landcoversNorthCaption': '',
#    'landcoversNorthClassifications': '10% MUC 11 (n) [Trees, Loosely Spaced, Evergreen - Needle Leaved]; 10% MUC 12 (n) [Trees, Loosely Spaced, Deciduous - Needle Leaved]; 10% MUC 32 (l) [Shrubs, Loosely Spaced, Short Deciduous]; 70% MUC 91 [Urban, Residential Property]',
#    'landcoversNorthExtraData': '(source: app, (compassData.horizon: 24.897774729192477))',
#    'landcoversNorthPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/02/1660193/original.jpg',
#    'landcoversRainingSnowing': 'false',
#    'landcoversSnowIce': 'false',
#    'landcoversSouthCaption': '',
#    'landcoversSouthClassifications': '10% MUC 11 (n) [Trees, Loosely Spaced, Evergreen - Needle Leaved]; 10% MUC 12 (n) [Trees, Loosely Spaced, Deciduous - Needle Leaved]; 10% MUC 32 (l) [Shrubs, Loosely Spaced, Short Deciduous]; 70% MUC 91 [Urban, Residential Property]',
#    'landcoversSouthExtraData': '(source: app, (compassData.horizon: 22.235261817092848))',
#    'landcoversSouthPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/02/1660197/original.jpg',
#    'landcoversStandingWater': 'false',
#    'landcoversUpwardCaption': '',
#    'landcoversUpwardExtraData': '(source: app, (compassData.horizon: 88.21020409017467))',
#    'landcoversUpwardPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/02/1660199/original.jpg',
#    'landcoversUserid': '398545',
#    'landcoversWestCaption': '',
#    'landcoversWestClassifications': '10% MUC 11 (n) [Trees, Loosely Spaced, Evergreen - Needle Leaved]; 10% MUC 12 (n) [Trees, Loosely Spaced, Deciduous - Needle Leaved]; 10% MUC 32 (l) [Shrubs, Loosely Spaced, Short Deciduous]; 70% MUC 91 [Urban, Residential Property]',
#    'landcoversWestExtraData': '(source: app, (compassData.horizon: 18.434525910775022))',
#    'landcoversWestPhotoUrl': 'https://data.globe.gov/system/photos/2020/06/02/1660198/original.jpg',
#    'organizationId': 'organizationId',
#    'organizationName': 'Bowling Green State University (USOHP793)',
#    'protocol': 'land_covers',
#    'siteId': 'siteId',
#    'siteName': '17TKG811058'},
#   'geometry': {'type': 'Point', 'coordinates': [-83.625603, 41.573917]}}]

# %%
data_df_land = pd.DataFrame(land_data)

# %%
land_list = []
key_land_data = ["coordinates", "landcoversMucCode"]
for index, row in data_df_land.iterrows():
    land_data_dict_1 = {**data_df_land.loc[index, "properties"], **data_df_land.loc[index, "geometry"] }
    land_list.append(land_data_dict_1)

    
land_df = pd.DataFrame(land_list)[key_land_data]
land_df
# Out:
#                 coordinates landcoversMucCode
# 0    [39.138221, 21.611502]               M94
# 1    [39.138221, 21.611502]               M91
# 2  [-105.235524, 40.014562]              null
# 3  [-105.258979, 40.019918]              null
# 4    [40.969218, 24.229192]               M81
# 5    [40.969218, 24.229192]               M81
# 6    [40.969218, 24.229192]               M81
# 7    [40.969218, 24.229192]               M81
# 8   [-83.625603, 41.573917]              null
# 9   [-83.625603, 41.573917]               M91

# %%
from math import radians, sin, cos, acos
max_dist = 500
def get_dist(coordOne, coordTwo):
    slat = radians(coordOne[0])
    slong = radians(coordOne[1])
    elat = radians(coordTwo[0])
    elong = radians(coordTwo[1])
    return 6371.01 * acos(sin(slat)*sin(elat) + cos(slat)*cos(elat)*cos(slong - elong)) * 1000
def in_range(coordOne, coordTwo):
    return abs(round(get_dist(coordOne, coordTwo))) <= max_dist

# %%
get_dist([33.169962,-96.700258], [33.165462,-96.700258])
# Out:
# 500.3779492185948

# %%
in_range([33.169962,-96.700258], [33.165462,-96.700258])
# Out:
# True
